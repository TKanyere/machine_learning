# %%
import random
import matplotlib.pyplot as plt
def est_pi(n):
    num_inside=0
    num_total=0
    a=[]
    b=[]
    theta=np.linspace(0,2*np.pi,100)
    r=1
    x1=r*np.cos(theta)
    x2=r*np.sin(theta)
    for _ in range(n):
        x=random.uniform(0,1)
        a.append(x)
        y=random.uniform(0,1)
        b.append(y)
        distance=(x**2+y**2)
        if distance<=1:
            num_inside+=1
        num_total+=1
    
    func=num_inside/num_total
    plt.figure(figsize = (8, 8))
    plt.ylim(0, 1)
    plt.xlim(0,1)
    plt.scatter(a,b,marker='x',s=0.1)
    plt.title('Estimation of pi using monty hall')
    plt.plot(x1,x2,color='r')
    print('pi=',4*func)
est_pi(100000)
# Out:
# pi= 3.1402
